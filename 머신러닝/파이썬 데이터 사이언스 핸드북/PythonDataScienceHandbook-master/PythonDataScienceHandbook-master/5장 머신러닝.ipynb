# %%
import seaborn as sns
iris = sns.load_dataset('iris')

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X_iris = iris.drop('species', axis=1)
X_iris.shape
# Out:
# (150, 4)

# %%
y_iris = iris['species']
y_iris.shape
# Out:
# (150,)

# %%
X = x[:, np.newaxis]
X.shape
# Out:
# (50, 1)

# %%
import seaborn as sns
sns.set()
sns.pairplot(iris,hue='species', size = 1.5)
# Out:
# C:\Users\admin\AppData\Local\conda\conda\envs\bk\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)

x = 10* rng.rand(50)
y = 2 * x-1 + rng.randn(50)
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept = True)

model.fit(x,y)

# %%
x.shape
# Out:
# (50,)

# %%
x[:,np.newaxis].shape
# Out:
# (50, 1)

# %%
x
# Out:
# array([3.74540119, 9.50714306, 7.31993942, 5.98658484, 1.5601864 ,
#        1.5599452 , 0.58083612, 8.66176146, 6.01115012, 7.08072578,
#        0.20584494, 9.69909852, 8.32442641, 2.12339111, 1.81824967,
#        1.8340451 , 3.04242243, 5.24756432, 4.31945019, 2.9122914 ,
#        6.11852895, 1.39493861, 2.92144649, 3.66361843, 4.56069984,
#        7.85175961, 1.99673782, 5.14234438, 5.92414569, 0.46450413,
#        6.07544852, 1.70524124, 0.65051593, 9.48885537, 9.65632033,
#        8.08397348, 3.04613769, 0.97672114, 6.84233027, 4.40152494,
#        1.22038235, 4.9517691 , 0.34388521, 9.09320402, 2.58779982,
#        6.62522284, 3.11711076, 5.20068021, 5.46710279, 1.84854456])

# %% [markdown]
# # 비지도 학습 예제: 붓꽃 차원 축소

# %% [markdown]
# ### Unsupervised learning example: Iris dimensionality
# As an example of an unsupervised learning problem, let's take a look at reducing the dimensionality of the Iris data so as to more easily visualize it. Recall that the Iris data is four dimensional: there are four features recorded for each sample.
#
# The task of dimensionality reduction is to ask whether there is a suitable lower-dimensional representation that retains the essential features of the data. Often dimensionality reduction is used as an aid to visualizing data: after all, it is much easier to plot data in two dimensions than in four dimensions or higher!
#
# Here we will use principal component analysis (PCA; see In Depth: Principal Component Analysis), which is a fast linear dimensionality reduction technique. We will ask the model to return two components—that is, a two-dimensional representation of the data.
#
# Following the sequence of steps outlined earlier, we have:

# %%
from sklearn.decomposition import PCA # 1. 모델 클래스 선택
model = PCA(n_components= 2) # 2. 초모수로 모델 인스턴스화
model.fit(X_iris)                  # 3.데이터에 적합. y는 지정 안함!
X_2D  = model.transform(X_iris) #  # 4.데이터를 2차원으로 변환

# %% [markdown]
# Now let's plot the results. A quick way to do this is to insert the results into the original Iris DataFrame, and use Seaborn's lmplot to show the results:

# %%
X_2D
# Out:
# array([[-2.68412563,  0.31939725],
#        [-2.71414169, -0.17700123],
#        [-2.88899057, -0.14494943],
#        [-2.74534286, -0.31829898],
#        [-2.72871654,  0.32675451],
#        [-2.28085963,  0.74133045],
#        [-2.82053775, -0.08946138],
#        [-2.62614497,  0.16338496],
#        [-2.88638273, -0.57831175],
#        [-2.6727558 , -0.11377425],
#        [-2.50694709,  0.6450689 ],
#        [-2.61275523,  0.01472994],
#        [-2.78610927, -0.235112  ],
#        [-3.22380374, -0.51139459],
#        [-2.64475039,  1.17876464],
#        [-2.38603903,  1.33806233],
#        [-2.62352788,  0.81067951],
#        [-2.64829671,  0.31184914],
#        [-2.19982032,  0.87283904],
#        [-2.5879864 ,  0.51356031],
#        [-2.31025622,  0.39134594],
#        [-2.54370523,  0.43299606],
#        [-3.21593942,  0.13346807],
#        [-2.30273318,  0.09870885],
#        [-2.35575405, -0.03728186],
#        [-2.50666891, -0.14601688],
#        [-2.46882007,  0.13095149],
# ...

# %%
X_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
X_2D[:,0]
# Out:
# array([-2.68412563, -2.71414169, -2.88899057, -2.74534286, -2.72871654,
#        -2.28085963, -2.82053775, -2.62614497, -2.88638273, -2.6727558 ,
#        -2.50694709, -2.61275523, -2.78610927, -3.22380374, -2.64475039,
#        -2.38603903, -2.62352788, -2.64829671, -2.19982032, -2.5879864 ,
#        -2.31025622, -2.54370523, -3.21593942, -2.30273318, -2.35575405,
#        -2.50666891, -2.46882007, -2.56231991, -2.63953472, -2.63198939,
#        -2.58739848, -2.4099325 , -2.64886233, -2.59873675, -2.63692688,
#        -2.86624165, -2.62523805, -2.80068412, -2.98050204, -2.59000631,
#        -2.77010243, -2.84936871, -2.99740655, -2.40561449, -2.20948924,
#        -2.71445143, -2.53814826, -2.83946217, -2.54308575, -2.70335978,
#         1.28482569,  0.93248853,  1.46430232,  0.18331772,  1.08810326,
#         0.64166908,  1.09506066, -0.74912267,  1.04413183, -0.0087454 ,
#        -0.50784088,  0.51169856,  0.26497651,  0.98493451, -0.17392537,
# ...

# %%
iris['PCA1'] = X_2D[:,0]
iris['PCA2'] = X_2D[:,1]

sns.lmplot("PCA1", "PCA2", hue='species', data = iris, fit_reg= False)

# %%
iris["PCA2"]
# Out:
# 0      0.319397
# 1     -0.177001
# 2     -0.144949
# 3     -0.318299
# 4      0.326755
#          ...
# 145    0.187532
# 146   -0.375317
# 147    0.078859
# 148    0.116628
# 149   -0.282661
# Name: PCA2, Length: 150, dtype: float64

# %%
iris["PCA1"]
# Out:
# 0     -2.684126
# 1     -2.714142
# 2     -2.888991
# 3     -2.745343
# 4     -2.728717
#          ...
# 145    1.944110
# 146    1.527167
# 147    1.764346
# 148    1.900942
# 149    1.390189
# Name: PCA1, Length: 150, dtype: float64

# %%
y_iris
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# PCA 알고리즘이 붓꽃종 레이블에 대한 지식이 없는데도 2차원 표현에서 종이 매우 잘 분리돼 있음을 볼 수 있음!! 이것은 앞에서 본 것처럼 비교적 단순한 분류 기법이 이 데이터 셋에 효과적일 수도 있음을 의미

# %% [markdown]
# # 비지도 학습:붓꽃 군집화

# %% [markdown]
# 강력한 군집화 기법인 가우스 혼합 모델(GMM, Gaussian mixture model)을 사용. GMM은 데이터를 가우스 블롭의 컬렉션으로 모델링

# %%
#from sklearn.mixture import GMM # 1. 모델 클래스 선택
from sklearn.cluster import KMeans
#model = KMeans(n_componets=3 ,  covariance_type = 'full') # 2. 초모수로 모델 인스턴스화
model = KMeans(n_clusters=3) # 2. 초모수로 모델 인스턴스화

model.fit(X_iris)     # 3. 데이터에 적합. y는 지정하지 않음!

Y_gmm = model.predict(X_iris) # 4. 군집레이블 결정

# %%
iris['cluster'] = Y_gmm
sns.lmplot("PCA1", "PCA2", data=iris, hue='species',
           col='cluster', fit_reg=False);

# %%
from sklearn.mixture import GMM      # 1. Choose the model class
model = GMM(n_components=3,
            covariance_type='full')  # 2. Instantiate the model with hyperparameters
model.fit(X_iris)                    # 3. Fit to data. Notice y is not specified!
y_gmm = model.predict(X_iris)        # 4. Determine cluster labels
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-54-df85f2dd883f> in <module>
# ----> 1 from sklearn.mixture import GMM      # 1. Choose the model class
#       2 model = GMM(n_components=3,
#       3             covariance_type='full')  # 2. Instantiate the model with hyperparameters
#       4 model.fit(X_iris)                    # 3. Fit to data. Notice y is not specified!
#       5 y_gmm = model.predict(X_iris)        # 4. Determine cluster labels
#
# ImportError: cannot import name 'GMM'

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.images.shape
# Out:
# (1797, 8, 8)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10, 10, figsize=(8, 8),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.1, wspace=0.1))

for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], cmap='binary', interpolation='nearest')
    ax.text(0.05, 0.05, str(digits.target[i]),
            transform=ax.transAxes, color='green')

# %%
from sklearn.manifold import Isomap
iso = Isomap(n_components=2)
iso.fit(digits.data)
data_projected = iso.transform(digits.data)
data_projected.shape
# Out:
# (1797, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=0)

# %%
X.reshape(50,)
# Out:
# array([3.74540119, 9.50714306, 7.31993942, 5.98658484, 1.5601864 ,
#        1.5599452 , 0.58083612, 8.66176146, 6.01115012, 7.08072578,
#        0.20584494, 9.69909852, 8.32442641, 2.12339111, 1.81824967,
#        1.8340451 , 3.04242243, 5.24756432, 4.31945019, 2.9122914 ,
#        6.11852895, 1.39493861, 2.92144649, 3.66361843, 4.56069984,
#        7.85175961, 1.99673782, 5.14234438, 5.92414569, 0.46450413,
#        6.07544852, 1.70524124, 0.65051593, 9.48885537, 9.65632033,
#        8.08397348, 3.04613769, 0.97672114, 6.84233027, 4.40152494,
#        1.22038235, 4.9517691 , 0.34388521, 9.09320402, 2.58779982,
#        6.62522284, 3.11711076, 5.20068021, 5.46710279, 1.84854456])

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(Xtrain, ytrain)
y_model = model.predict(Xtest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-3cc5f91f75ce> in <module>
#       1 from sklearn.naive_bayes import GaussianNB
#       2 model = GaussianNB()
# ----> 3 model.fit(Xtrain, ytrain)
#       4 y_model = model.predict(Xtest)
#
# ~\AppData\Local\conda\conda\envs\bk\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     206         y = column_or_1d(y, warn=True)
#     207         return self._partial_fit(X, y, np.unique(y), _refit=True,
# --> 208                                  sample_weight=sample_weight)
#     209
#     210     def _check_X(self, X):
#
# ~\AppData\Local\conda\conda\envs\bk\lib\site-packages\sklearn\naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     370             self.classes_ = None
#     371
# --> 372         if _check_partial_fit_first_call(self, classes):
# ...

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris,
                                                random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB # 1. choose model class
model = GaussianNB()                       # 2. instantiate model
model.fit(Xtrain, ytrain)                  # 3. fit model to data
y_pred = model.predict(Xtest)             # 4. predict on new data

y2_pred = model.predict(Xtrain)

# %%
y2_pred
# Out:
# array(['versicolor', 'virginica', 'virginica', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'virginica', 'setosa', 'setosa',
#        'setosa', 'versicolor', 'setosa', 'setosa', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'versicolor',
#        'virginica', 'versicolor', 'setosa', 'virginica', 'virginica',
#        'setosa', 'setosa', 'virginica', 'setosa', 'virginica',
#        'virginica', 'versicolor', 'versicolor', 'virginica', 'virginica',
#        'setosa', 'versicolor', 'versicolor', 'virginica', 'versicolor',
#        'virginica', 'versicolor', 'setosa', 'setosa', 'setosa',
#        'virginica', 'setosa', 'virginica', 'virginica', 'virginica',
#        'setosa', 'setosa', 'versicolor', 'setosa', 'virginica',
#        'versicolor', 'virginica', 'virginica', 'versicolor', 'virginica',
#        'virginica', 'versicolor', 'setosa', 'versicolor', 'setosa',
#        'versicolor', 'virginica', 'setosa', 'versicolor', 'setosa',
# ...

# %%
# Out:
# 0.9464285714285714

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest, y_model)
# Out:
# 0.9736842105263158

# %%
model.score(Xtest,ytest)
# Out:
# 0.9736842105263158

# %%
from sklearn.metrics import confusion_matrix

mat = confusion_matrix(ytest, y_pred)
mat
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
mat2= confusion_matrix(ytrain,y2_pred)

# %%
mat2
# Out:
# array([[37,  0,  0],
#        [ 0, 31,  3],
#        [ 0,  3, 38]], dtype=int64)

# %%
sns.heatmap(mat, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value');

# %%
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(y_pred,ytest) # 위치 바뀌면 전치행렬 되네???

sns.heatmap(matrix, annot = True)
plt.show()

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(Xtrain, ytrain)
y_model = model.predict(Xtest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-3cc5f91f75ce> in <module>
#       1 from sklearn.naive_bayes import GaussianNB
#       2 model = GaussianNB()
# ----> 3 model.fit(Xtrain, ytrain)
#       4 y_model = model.predict(Xtest)
#
# ~\AppData\Local\conda\conda\envs\bk\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     206         y = column_or_1d(y, warn=True)
#     207         return self._partial_fit(X, y, np.unique(y), _refit=True,
# --> 208                                  sample_weight=sample_weight)
#     209
#     210     def _check_X(self, X):
#
# ~\AppData\Local\conda\conda\envs\bk\lib\site-packages\sklearn\naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     370             self.classes_ = None
#     371
# --> 372         if _check_partial_fit_first_call(self, classes):
# ...

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.images.shape
# Out:
# (1797, 8, 8)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10, 10, figsize=(8, 8),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.1, wspace=0.1))

for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], cmap='binary', interpolation='nearest')
    ax.text(0.05, 0.05, str(digits.target[i]),
            transform=ax.transAxes, color='green')

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(Xtrain, ytrain)
y_model = model.predict(Xtest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-3cc5f91f75ce> in <module>
#       1 from sklearn.naive_bayes import GaussianNB
#       2 model = GaussianNB()
# ----> 3 model.fit(Xtrain, ytrain)
#       4 y_model = model.predict(Xtest)
#
# ~\AppData\Local\conda\conda\envs\bk\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     206         y = column_or_1d(y, warn=True)
#     207         return self._partial_fit(X, y, np.unique(y), _refit=True,
# --> 208                                  sample_weight=sample_weight)
#     209
#     210     def _check_X(self, X):
#
# ~\AppData\Local\conda\conda\envs\bk\lib\site-packages\sklearn\naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     370             self.classes_ = None
#     371
# --> 372         if _check_partial_fit_first_call(self, classes):
# ...
