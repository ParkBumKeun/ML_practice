# %%
import cv2
cv2.__version__
# Out:
# '4.1.2'

# %%
import numpy as np
import cv2

import matplotlib.pyplot as plt

image = cv2.imread("images/plane.jpg", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# %%
image
# Out:
# array([[140, 136, 146, ..., 132, 139, 134],
#        [144, 136, 149, ..., 142, 124, 126],
#        [152, 139, 144, ..., 121, 127, 134],
#        ...,
#        [156, 146, 144, ..., 157, 154, 151],
#        [146, 150, 147, ..., 156, 158, 157],
#        [143, 138, 147, ..., 156, 157, 157]], dtype=uint8)

# %%
image.shape
# Out:
# (2270, 3600)

# %%
image_bgr = cv2.imread('images/plane.jpg', cv2.IMREAD_COLOR)

# %%
plt.imshow(image_bgr)
plt.show()

# %%
image_bgr
# Out:
# array([[[195, 144, 111],
#         [191, 140, 107],
#         [201, 150, 117],
#         ...,
#         [187, 136, 103],
#         [194, 143, 110],
#         [189, 138, 105]],
#
#        [[199, 148, 115],
#         [191, 140, 107],
#         [204, 153, 120],
#         ...,
#         [197, 146, 113],
#         [179, 128,  95],
#         [181, 130,  97]],
#
#        [[207, 156, 123],
#         [194, 143, 110],
#         [199, 148, 115],
#         ...,
#         [176, 125,  92],
#         [182, 131,  98],
#         [189, 138, 105]],
#
#        ...,
#
#        [[211, 162, 124],
#         [201, 152, 114],
#         [201, 149, 112],
#         ...,
#         [189, 159, 140],
#         [186, 156, 137],
#         [183, 153, 134]],
#
#        [[201, 152, 114],
#         [205, 156, 118],
#         [202, 153, 115],
#         ...,
#         [188, 158, 139],
#         [190, 160, 141],
#         [187, 160, 140]],
#
#        [[200, 148, 111],
#         [195, 143, 106],
#         [204, 152, 115],
# ...

# %%
image_rgb = cv2.cvtColor(image_bgr,cv2.COLOR_BGR2RGB)

# %%
image_rgb
# Out:
# array([[[111, 144, 195],
#         [107, 140, 191],
#         [117, 150, 201],
#         ...,
#         [103, 136, 187],
#         [110, 143, 194],
#         [105, 138, 189]],
#
#        [[115, 148, 199],
#         [107, 140, 191],
#         [120, 153, 204],
#         ...,
#         [113, 146, 197],
#         [ 95, 128, 179],
#         [ 97, 130, 181]],
#
#        [[123, 156, 207],
#         [110, 143, 194],
#         [115, 148, 199],
#         ...,
#         [ 92, 125, 176],
#         [ 98, 131, 182],
#         [105, 138, 189]],
#
#        ...,
#
#        [[124, 162, 211],
#         [114, 152, 201],
#         [112, 149, 201],
#         ...,
#         [140, 159, 189],
#         [137, 156, 186],
#         [134, 153, 183]],
#
#        [[114, 152, 201],
#         [118, 156, 205],
#         [115, 153, 202],
#         ...,
#         [139, 158, 188],
#         [141, 160, 190],
#         [140, 160, 187]],
#
#        [[111, 148, 200],
#         [106, 143, 195],
#         [115, 152, 204],
# ...

# %%
plt.imshow(image_rgb)
plt.show()

# %%
# 전처리를 위해 이미지를 저장
# imwrite 를 사용
import cv2 
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread("images/plane.jpg", cv2.IMREAD_GRAYSCALE)

cv2.imwrite("images/plane_new.jpg",image)
# Out:
# True

# %%
# 이미지 크기 변경

import cv2 
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread("images/plane.jpg", cv2.IMREAD_GRAYSCALE)

image_50x50 = cv2.resize(image, (50,50))

cv2.imwrite("images/plane_50x50.jpg",image_50x50)
# Out:
# True

# %%
## 이미지 자르기

import cv2 
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread("images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)

image_cropped =image[:,:128]

# %%
plt.imshow(image_cropped, cmap='gray')
plt.axis('off')
plt.show()

# %%
# 이미지 흐리게 하기


import cv2 
import numpy as np
import matplotlib.pyplot as plt

# 흑백 이미지로 로드
image = cv2.imread("images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)

# 이미지를 흐리게, 각 픽셀 주변의 5x5 커널 평균값으로 이미지를 흐리게 함. 커널 사이즈 (5,5) 
image_blurry = cv2.blur(image,(5,5))

# 이미지를 출력
plt.imshow(image_blurry, cmap ='gray')
plt.axis('off')
plt.show()

# %%
image_very_blurry=cv2.blur(image,(100,100))
plt.imshow(image_very_blurry,cmap='gray')
plt.show()

# %%
image_very_blurry=cv2.blur(image,(100,100))
plt.imshow(image_very_blurry,cmap='gray')
plt.axis('off')
plt.show()

# %%
image_very_blurry=cv2.blur(image,(100,100))
plt.imshow(image_very_blurry,cmap='gray')
plt.xticks([])
plt.show()

# %%
# kernel 값을 주고  filter2D 함수로 커널을 이미지에 직접 적용해 비슷한 흐림 효과를 만듬

kernel = np.ones((5,5)) / 25.0 
kernel
# Out:
# array([[0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04]])

# %%
# 커널을 적용
image_kernel = cv2.filter2D(image, -1 , kernel) # -1은 뭐임

plt.imshow(image_kernel, cmap='gray')
plt.axis('off')
plt.show()

# %%
# 커널을 적용
image_kernel = cv2.filter2D(image, 100000222 , kernel) # -1은 뭐임

plt.imshow(image_kernel, cmap='gray')
plt.axis('off')
plt.show()

# %%
# 커널을 적용
image_kernel = cv2.filter2D(image,2, kernel) # -1은 뭐임

plt.imshow(image_kernel, cmap='gray')
plt.axis('off')
plt.show()

# %%
######### 가우시안 블러를 적용

image_very_blurry = cv2.GaussianBlur(image, (5,5),0) # 여기서 0은 X축(너비) 방향의 표준편차. 0으로 지정시 ((너비-1)*0.5-1)*0.3+0.8
                                                     # Y축 방향의 표준편차는 기본값이 0임.

plt.imshow(image_very_blurry, cmap='gray')
plt.axis('off')
plt.show()

# %%
print(image)
# Out:
# [[152 150 149 ... 142 142 142]
#  [137 135 134 ... 128 127 127]
#  [135 133 133 ... 127 126 126]
#  ...
#  [150 150 151 ... 168 167 167]
#  [151 151 152 ... 167 166 166]
#  [152 152 153 ... 167 166 166]]

# %%
print(image_blurry)
# Out:
# [[137 138 138 ... 130 130 130]
#  [138 138 138 ... 130 130 130]
#  [137 137 138 ... 130 130 130]
#  ...
#  [151 151 152 ... 168 167 167]
#  [151 152 152 ... 167 167 167]
#  [151 152 153 ... 167 167 167]]

# %%
print(image_very_blurry) # 가우시안이랑 그냥 블러랑 값이 다름 볼때는 비슷해도 !
# Out:
# [[141 141 140 ... 133 133 133]
#  [139 139 138 ... 131 131 131]
#  [135 135 135 ... 128 128 128]
#  ...
#  [150 151 152 ... 168 167 167]
#  [151 151 152 ... 167 167 166]
#  [151 152 153 ... 167 166 166]]

# %%
# getGaussianKernel 함수를 이용해 1차원 배열을 만들고 넘파이 outer 함수로 외적을 계산

gaus_vector = cv2.getGaussianKernel(5,0)
gaus_vector
# Out:
# array([[0.0625],
#        [0.25  ],
#        [0.375 ],
#        [0.25  ],
#        [0.0625]])

# %%
# 벡터를 외적하여 커널을 만듬
gaus_kernel = np.outer(gaus_vector, gaus_vector)
gaus_kernel
# Out:
# array([[0.00390625, 0.015625  , 0.0234375 , 0.015625  , 0.00390625],
#        [0.015625  , 0.0625    , 0.09375   , 0.0625    , 0.015625  ],
#        [0.0234375 , 0.09375   , 0.140625  , 0.09375   , 0.0234375 ],
#        [0.015625  , 0.0625    , 0.09375   , 0.0625    , 0.015625  ],
#        [0.00390625, 0.015625  , 0.0234375 , 0.015625  , 0.00390625]])

# %%
# 해결에서와 같이 직접 만든 커널을 filter2D함수에 적용 가능.

# 커널을 적용 
image_kernel = cv2.filter2D(image, -1 , gaus_kernel) # 두번째 매개변수는 픽셀값의 범위를 지정하는 것으로 -1 이면 입력과 동일한 범위 유지.

plt.imshow(image_kernel, cmap='gray')
plt.axis('off')
plt.show()

# %%
# 이미지 선명하게 하기
# 대상 픽셀을 강조하는 커널을 만들고 filter2D를 사용해 이미지에 커널을 적용

# 라이브러리를 임포트
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread("images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)

# 커널 생성 
kernel = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])  
''' 
 선명하게 하는 것은 흐리게 하는 것고 ㅏ비슷하다. 주변 피겟ㄹ값의 평균을 계산하는 커널을 사용하는 대신 중앙 픽셀을 부각하는 커널을 만듬. 이로
 인한 효과로 이미지의 경계선에 대비가 더욱 두드러짐.
'''
# 이미지를 선명하게 만듬
image_sharp = cv2.filter2D(image,-1, kernel)

plt.imshow(image_sharp, cmap='gray')
plt.axis('off')
plt.show()

# %%
image2 = cv2.imread("images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)

# 커널 생성 
kernel = np.array([[0,-1,0],[-1,4,-1],[0,-1,0]])   # 위와 차이 비교
''' 
 선명하게 하는 것은 흐리게 하는 것고 ㅏ비슷하다. 주변 피겟ㄹ값의 평균을 계산하는 커널을 사용하는 대신 중앙 픽셀을 부각하는 커널을 만듬. 이로
 인한 효과로 이미지의 경계선에 대비가 더욱 두드러짐.
'''
# 이미지를 선명하게 만듬
image_sharp = cv2.filter2D(image,-1, kernel)

plt.imshow(image_sharp, cmap='gray')
plt.axis('off')
plt.show()

# %%
image2 = cv2.imread("images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)

# 커널 생성 
kernel = np.array([[0,-1,0],[-1,8,-1],[0,-1,0]])   # 위와 차이 비교
''' 
 선명하게 하는 것은 흐리게 하는 것고 ㅏ비슷하다. 주변 피겟ㄹ값의 평균을 계산하는 커널을 사용하는 대신 중앙 픽셀을 부각하는 커널을 만듬. 이로
 인한 효과로 이미지의 경계선에 대비가 더욱 두드러짐.
'''
# 이미지를 선명하게 만듬
image_sharp = cv2.filter2D(image,-1, kernel)

plt.imshow(image_sharp, cmap='gray')
plt.axis('off')
plt.show()

# %%
image2 = cv2.imread("images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)

# 커널 생성 
kernel = np.array([[0,-3,0],[-3,15,-3],[0,-3,0]])   # 위와 차이 비교
''' 
 선명하게 하는 것은 흐리게 하는 것고 ㅏ비슷하다. 주변 피겟ㄹ값의 평균을 계산하는 커널을 사용하는 대신 중앙 픽셀을 부각하는 커널을 만듬. 이로
 인한 효과로 이미지의 경계선에 대비가 더욱 두드러짐.
'''
# 이미지를 선명하게 만듬
image_sharp = cv2.filter2D(image,-1, kernel)

plt.imshow(image_sharp, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# 8.7 대비 높이기

# %%
# 이미지 픽셀 사이의 대비를 증가

# 히스토그램 평활화!!!!는 객체의 형태가 두드러지도록 만들어주는 이미지 처리 도구.

import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('images/plane_256x256.jpg', cv2.IMREAD_GRAYSCALE)

# 이미지 대비를 향상 cv2.equalizeHist!!

image_enhanced = cv2.equalizeHist(image)

plt.imshow(image_enhanced, cmap='gray')
plt.axis('off')
plt.show()

# %%
# 컬러 이미지는 먼저 YUV 컬러 포맷으로 변환해야 함. Y는 루마 또는 밝기 이고 U와 V는 컬러를 나타냄 변환 뒤 equalizeHist를 적용 가능
# 그다음 다시 BGR이나 RGB로 바꿈

# 이미지를 로드 
image_bgr = cv2.imread('images/plane.jpg')
image_yuv = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2YUV)

# 히스토그램을  평활화 적용
plt.imshow(image_yuv, )
plt.axis('off')
plt.show()

# %%
# 히스토그램 평활화를 적용
image_yuv[:,:,0] = cv2.equalizeHist(image_yuv[:,:,0])

# RGB로 변환 대비 상승!
image_rgb=cv2.cvtColor(image_yuv, cv2.COLOR_YUV2RGB)
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %% [markdown]
# 히스토그램 평활화가 어떻게 작동하는지 자세히 설명하는 것은  이 책의 범위를 벗어나므로,간단히 설명하면 픽셀값의 범위가 커지도록 이미지를 변환하는 것임.
#
# 히스토그램 평활화는 관심 대상을 다른 객체나 배경과 잘 구분되도록 만들어 줌.

# %%
# 컬러 이미지는 먼저 YUV 컬러 포맷으로 변환해야 함. Y는 루마 또는 밝기 이고 U와 V는 컬러를 나타냄 변환 뒤 equalizeHist를 적용 가능
# 그다음 다시 BGR이나 RGB로 바꿈

# 이미지를 로드 
image_bgr2 = cv2.imread('images/plane.jpg')
image_yuv2= cv2.cvtColor(image_bgr2, cv2.COLOR_BGR2YUV)

# 히스토그램 평활화를 적용
image_yuv[:,:,0] = cv2.equalizeHist(image_yuv[:,:,0])

# RGB로 변환 대비 상승!
image_rgb2=cv2.cvtColor(image_yuv2, cv2.COLOR_YUV2RGB)
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %% [markdown]
# # 8.8 색깔 구분하기

# %% [markdown]
# 이미지에서 한 색깔을 구분 ( 색 범위를 정의하고 이미지에 마스크를 적용)

# %%
# f라이브러리를 임포트

import cv2
import numpy as np
import matplotlib.pyplot as plt 

image_bgr = cv2.imread('images/plane_256x256.jpg')

# BGR에서 HSV 로 변환
image_hsv = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2HSV)

# HSV 에서 파랑 값의 범위를 정의

lower_blue = np.array([50,100,50])
upper_blue= np.array([130,255,255])

# 마스크를 만듬
mask = cv2.inRange(image_hsv, lower_blue,upper_blue)  # image_hsv 에서 hsv값 범위 lower_blue에서 upper_blue 범위로 격리 시킬 값 지정.

# 이미지에 마스크를 적용                   ###################################### 
image_bgr_masked = cv2.bitwise_and(image_bgr, image_bgr, mask = mask) # 이미지에서 적용할 마스크 생성.(마스크의 흰색 영역만 유지)

# BGR 에서 RGB로 변환

image_rgb = cv2.cvtColor(image_bgr_masked, cv2.COLOR_BGR2RGB)

# 이미지를 출력

# %%
# BGR에서 HSV 로 변환
image_hsv = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2HSV)

plt.imshow(image_hsv)
plt.axis('off')
plt.show()

# %%
 # 마스크 hsv일때 
plt.imshow(mask)
plt.axis('off')
plt.show()

# %%
 

plt.imshow(image_bgr_masked)
plt.axis('off')
plt.show()

# %%
 

plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
 # 마스크 춫력

plt.imshow(mask, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# # 8.9 이미지 이진화하기  ( 이해가 안가...)

# %% [markdown]
# 주어진 이미지를 단순한 버전으로 출력 - 이미지 이진화(임계처리)는 어떤 값보다 큰 값을 가진 픽셀을 흰색으로 만들고 작은 값을 가진 픽셀은 검은색으로 만드는 과정. 더 고급 기술은 적응적 이진화(임계처리)로,픽셀의 임곗값이 주변 픽셀의 강도에 의해 결정됌. 이미지 안의 영역마다 빛 조건이 달라질 때 도움이 됌.

# %%
# 임계처리 thresholding ,, 적응적 이진화 임계처리 - adaptive thresholding

# %%
# f라이브러리를 임포트

import cv2
import numpy as np
import matplotlib.pyplot as plt 

image_gray = cv2.imread('images/plane_256x256.jpg',cv2.IMREAD_GRAYSCALE)

# 적응적 이진화를 적용
max_output_value =255            # 출력 픽셀 강도의 최대값을 결정

neighborhood_size = 99        

subtract_from_mean = 10

image_binarized = cv2.adaptiveThreshold(image_gray,max_output_value,
                                        cv2.ADAPTIVE_THRESH_GAUSSIAN_C,  # 픽셀의 임곗값을 주변 픽셀 강도의 가중치 합으로 설정.가중치는 가우시안 윈도에 의해 결정.
                                        # 또는 cv2.ADAPTIVE_THRESH_MEAN_C로 주변 픽셀의 평균을 임곗값으로 설정. 
                                        cv2.THRESH_BINARY,
                                        neighborhood_size, 
                                        subtract_from_mean)

# %%
cv2.adaptiveThreshold?

##
adaptiveThreshold(src, maxValue, adaptiveMethod, thresholdType, blockSize, C[, dst]) -> dst
.   @brief Applies an adaptive threshold to an array.
.   
.   The function transforms a grayscale image to a binary image according to the formulae:
.   -   **THRESH_BINARY**
.       \f[dst(x,y) =  \fork{\texttt{maxValue}}{if \(src(x,y) > T(x,y)\)}{0}{otherwise}\f]
.   -   **THRESH_BINARY_INV**
.       \f[dst(x,y) =  \fork{0}{if \(src(x,y) > T(x,y)\)}{\texttt{maxValue}}{otherwise}\f]
.   where \f$T(x,y)\f$ is a threshold calculated individually for each pixel (see adaptiveMethod parameter).
.   
.   The function can process the image in-place.
.   
.   @param src Source 8-bit single-channel image.
.   @param dst Destination image of the same size and the same type as src.
.   @param maxValue Non-zero value assigned to the pixels for which the condition is satisfied
.   @param adaptiveMethod Adaptive thresholding algorithm to use, see #AdaptiveThresholdTypes.
.   The #BORDER_REPLICATE | #BORDER_ISOLATED is used to process boundaries.
.   @param thresholdType Thresholding type that must be either #THRESH_BINARY or #THRESH_BINARY_INV,
.   see #ThresholdTypes.
.   @param blockSize Size of a pixel neighborhood that is used to calculate a threshold value for the
.   pixel: 3, 5, 7, and so on.
.   @param C Constant subtracted from the mean or weighted mean (see the details below). Normally, it
.   is positive but may be zero or negative as well.
.   
.   @sa  threshold, blur, GaussianBlur

# %%
plt.imshow(image_binarized)
plt.axis('off')
plt.show()

# %%
plt.imshow(image_binarized, cmap='gray')
plt.axis('off')
plt.show()

# %%
image_binarized = cv2.adaptiveThreshold(image_gray,max_output_value,
                                       cv2.ADAPTIVE_THRESH_MEAN_C,
                                        # 또는 cv2.ADAPTIVE_THRESH_MEAN_C로 주변 픽셀의 평균을 임곗값으로 설정. 
                                        cv2.THRESH_BINARY,
                                        neighborhood_size, # 픽셀 임곗값 결정에 사용하는 주변 영역 크기
                                        subtract_from_mean) # 계산된 임곗값에서 뺄 상수(임곗값을 수동으로 미세 조정하는 데 사용하는 값)

# %%
plt.imshow(image_binarized, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# 이미지 이진화의 주요 장점은 대부분 중요한 요소를 유지하면서 이미지의 노이즈를 제거하는 것. 예를 들어 이미지 이진화는 인쇄물을 찍은 사진에서 글자를 분리해내기 위해 자주 사용

# %% [markdown]
#  # 8.10 배경 제거하기 (이해안감)

# %% [markdown]
# 이미지의 전경만 분리 - 원하는 전경 주위에 사각형 박스를 그리고 그랩컷 알고리즘을 실행

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 이미지를 로드하고 RGB로 변환

image_bgr = cv2.imread('images/plane_256x256.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# 사각형 좌표: 시작점의 x, 시작점의 y, 너비 ,높이
rectangle = (0,56,256,150)

# 초기 마스크를 만듬.
mask = np.zeros(image_rgb.shape[:2],np.uint8)

# grabCut을 실행.
bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)


# grabCut을 실행
cv2.grabCut(image_rgb, # 원본 이미지
           mask, # mask
           rectangle, # 사각형
           bgdModel, # 배경을 위한 임시 배열
           fgdModel, #  전경을 위한 임시 배열
           5, # 반복 횟수
           cv2.GC_INIT_WITH_RECT) # 사각형을 사용한 초기화)
            
            
# 배경인 곳은 0, 그외에는 1로 설정한 마스크를 만듬.
mask_2 = np.where((mask==2)| (mask==0),0,1).astype('uint8')

# 이미지에 새로운 마스크를 곱해 배경을 제외
image_rgb_nobg = image_rgb * mask_2[:,:,np.newaxis]

# 이미지를 출력
plt.imshow(image_rgb_nobg)
plt.axis('off')
plt.show()

# %% [markdown]
# 여기에서 첫 번째로 언급할 것은 그랩컷이 잘 작동하더라도 여전히 이미지에 남은 배경이 있다는 점입니다. 이때 다시 처음으로 돌아가서 직접 이 영역을 배경으로 지정할 수 있습니다. 하지만 실전에서 수천 장의 이미지를 각각 수동으로 고치는 것은 불가능합니다. 이미지에 일부 배경이 남아 있는 것을 수용하는 편이 좋습니다.

# %%
image_rgb.shape[:2] ##  0, 1
# Out:
# (256, 256)

# %%
mask.shape
# Out:
# (256, 256)

# %%
# 마스크 출력  
plt.imshow(mask, cmap='gray') # 사각형은 위에서 조정함
plt.show()

# %%
plt.imshow(mask_2, cmap='gray')

plt.show()

# %% [markdown]
# 그랩컷 알고리즘(http://bit.ly/2wgbPIS) 참조필 !! 이해안가

# %% [markdown]
# # 8.12 모서리 감지하기

# %% [markdown]
# 이미지에서 모서리 감지. Haris 모서리 감지 OpenCV 구현인 cornerHarris 사용.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 흑백 이미지로 로드
image_bgr = cv2.imread("images/plane_256x256.jpg")
imgae_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY) # 밑에 cornerHarris 하려고 float으로 타입변경.
image_gray = np.float32(image_gray)

# 모서리 감지 매개변수를 설정.
block_size= 2
aperture =29
free_parameter =0.04

# 모서리를 감지
detector_responses = cv2.cornerHarris(image_gray,block_size, aperture,free_parameter)

# 모서리 표시를 부각
detector_responses = cv2.dilate(detector_responses,None)

# 임곗값보다 큰 감지 결과만 남기고 흰색으로 표시
threshold = 0.02 

image_bgr[detector_responses> threshold* detector_responses.max()] = [255,255,255]

# %%
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray,cmap='gray')
plt.show()

# %% [markdown]
# 해리스 모서리 감지기는 두 개의 경계선이 교차하는 지점을 감지하는 방법으로 널리 사용. 모서리를 감지하려는 이유는 경계선을 감지하는 것과 같음. 모서리는 정보가 맡은 포인트.
#
# cornerHarris에서 block_size는 각 픽셀에서 모서리 감지에 사용되는 이웃 픽셀 크기. aperture는 소벨 커널 크기 (몰라도 됌.) 마지막으로 값이 클수록 부드러운 모서리를 구별하는 매개변수  (free_parameter값 작을수록 하얀거 더커짐

# %%
free_parameter =0.000000001

# 모서리를 감지
detector_responses = cv2.cornerHarris(image_gray,block_size, aperture,free_parameter)

# 모서리 표시를 부각
detector_responses = cv2.dilate(detector_responses,None)

# 임곗값보다 큰 감지 결과만 남기고 흰색으로 표시
threshold = 0.02 

image_bgr[detector_responses> threshold* detector_responses.max()] = [255,255,255]

# %%
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray,cmap='gray')
plt.show()

# %%
# 가능성이 높은 모서리를 출력
plt.imshow(detector_responses, cmap='gray')
plt.show()

# %% [markdown]
# 임곗값을 적용하여 가장 가능성이 높은 모서리만 남기기. 또는 해리스 감지기와 유사한 방식으로 작동하는
# Shi-Tomasi 모서리 감지기(goodFeaturesToTrakc)를 사용해 뚜렷하게 나타난 모서리를 지정된 개수만큼 찾아냄
#
# goodFeaturesToTrack은 세개의 주요 매개변수가 있음. 감지할 모서리 개수, 모서리가 될 최소 품질 (0에서 1사이).
# 모서리 사이의 최소 유클리드 거리

# %%
image_bgr = cv2.imread('images/plane_256x256.jpg')
image_gray = cv2.cvtColor(image_bgr,cv2.COLOR_BGR2GRAY)

# 감지할 모서리 수 

corners_to_detect = 10

minimum_quality_score = 0.05

minimum_distance = 25

# 모서리를 감지 
corners= cv2.goodFeaturesToTrack(image_gray, corners_to_detect,minimum_quality_score,minimum_distance)

corners = np.float32(corners)

# 모서리마다 흰 원을 그림

for corner in corners:
    x,y = corner[0]
    cv2.circle(image_bgr,(x,y), 10,(255,255,255),-1)
    
# 흑백 이미지로 변환
image_gray2 = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)

# 이미지를 출력.
plt.imshow(image_gray2, cmap = 'gray')
plt.axis('off')
plt.show()

# %% [markdown]
# OpenCV의 cornerHarris(http://bit.ly/2MewisG)
#
#
# OpenCV의 goodFeaturesToTrack(http://bit.ly/2X1Gm92)

# %%
image_bgr = cv2.imread('images/plane_256x256.jpg')
image_gray = cv2.cvtColor(image_bgr,cv2.COLOR_BGR2GRAY)

# 감지할 모서리 수 

corners_to_detect = 300

minimum_quality_score = 0.000001

minimum_distance = 1

# 모서리를 감지 
corners= cv2.goodFeaturesToTrack(image_gray, corners_to_detect,minimum_quality_score,minimum_distance)

corners = np.float32(corners)

# 모서리마다 흰 원을 그림

for corner in corners:
    x,y = corner[0]
    cv2.circle(image_bgr,(x,y), 3,(255,255,255),-1)
    
# 흑백 이미지로 변환
image_gray2 = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)

# 이미지를 출력.
plt.imshow(image_gray2, cmap = 'gray')
plt.axis('off')
plt.show()

# %% [markdown]
# # 8.13 머신러닝 특성 만들기

# %% [markdown]
# 이미지를 머신러닝에 필요한 샘플로 변환. - 넘파이 flatten 메서드를 사용해 이미지 데이터가 담긴 다차원 배열을 샘플값이 담긴 벡터로 변환.

# %%
image_gray222 = cv2.imread('images/plane_256x256.jpg', cv2.IMREAD_GRAYSCALE)
image_10x10=cv2.resize(image_gray222,(10,10))

image_10x10.flatten()
# Out:
# array([133, 130, 130, 129, 130, 129, 129, 128, 128, 127, 135, 131, 131,
#        131, 130, 130, 129, 128, 128, 128, 134, 132, 131, 131, 130, 129,
#        129, 128, 130, 133, 132, 158, 130, 133, 130,  46,  97,  26, 132,
#        143, 141,  36,  54,  91,   9,   9,  49, 144, 179,  41, 142,  95,
#         32,  36,  29,  43, 113, 141, 179, 187, 141, 124,  26,  25, 132,
#        135, 151, 175, 174, 184, 143, 151,  38, 133, 134, 139, 174, 177,
#        169, 174, 155, 141, 135, 137, 137, 152, 169, 168, 168, 179, 152,
#        139, 136, 135, 137, 143, 159, 166, 171, 175], dtype=uint8)

# %%
plt.imshow(image_10x10,cmap='gray')
plt.show()

# %%
image_10x10.shape
# Out:
# (10, 10)

# %%
image_10x10.flatten().shape
# Out:
# (100,)

# %%
 ## flatten() 할 때 주의할 점은  gray 이미지에 비해 color 이미지는 channel 값까지 곱해져 3배가 됌.

# %% [markdown]
# # 8.14 평균 색을 특성으로 인코딩하기

# %% [markdown]
# 이미지의 컬러를 바탕으로 한 특성이 필요 - 이미지의 각 픽셀은 여러 컬러 채널 (보통 세 개:빨강,초록,파랑)의 조합으로 표현.
# 빨강,초록 ,파랑 채널의 평균값을 계산해 이미지의 평균 컬러를 나타내는 세개의 컬러 특성을 만듬.
#
# cv2.mean(이미지)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# BGR 이미지로 로드
image_bgr = cv2.imread("images/plane_256x256.jpg", cv2.IMREAD_COLOR)

# 각 채널의 평균을 계산
channels = cv2.mean(image_bgr)
channels
# Out:
# (169.0235595703125, 133.11940002441406, 90.52377319335938, 0.0)

# %%
# 파랑과 빨강을 바꿈 (BGR에서 RGB로 만듬)
observation = np.array([(channels[2], channels[1],channels[0])])

# 채널 평균값을 확인
observation
# Out:
# array([[ 90.52377319, 133.11940002, 169.02355957]])

# %%
plt.imshow(observation)
plt.axis('off')
plt.show()

# %% [markdown]
# # 8.15 컬러 히스토그램을 특성으로 인코딩

# %% [markdown]
# 이미지에 나타난 컬러를 표현하는 일련의 특성을 만듬. - 각 컬러 채널에 대해 히스토그램을 계산.

# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt

# 이미지 로드 
image_bgr= cv2.imread("images/plane_256x256.jpg", cv2.IMREAD_COLOR)

image_rgb=cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# 특성 값을 담을 리스트
features = []

# 각 컬러 채널에 대해 히스토 그램 계산
colors = ('r','g','b')

# 각 채널을 반복하면서 히스토그램을 계산하고 리스트에 추가

for i,channel in enumerate(colors):
    histogram =cv2.calcHist([image_rgb], # 이미지
                            [i], # 채널 인덱스
                            None, # 마스크 없음
                            [256],  # 히스토그램 크기
                            [0,256]) # 범위 # 0 초과 256 미만 정수 가짐.
                           
    features.extend(histogram)
    
# 샘플의 특성값으로 벡터를 만듬

observation = np.array(features).flatten()

# 처음 다섯 개의 특성 출력
observation[0:5]
# Out:
# array([1027.,  217.,  182.,  146.,  146.], dtype=float32)

# %%
features[0]
# Out:
# array([1027.], dtype=float32)

# %%
j=0
for i in features:

    j+=1
j
# Out:
# 768

# %%
plt.plot(histogram,color=channel)
plt.show()

# %%
plt.plot(histogram,color=channel)
plt.xlim([0,256])
plt.show()

# %%
for i,channel in enumerate(colors):
    histogram =cv2.calcHist([image_rgb], # 이미지
                            [i], # 채널 인덱스
                            None, # 마스크 없음
                            [256],  # 히스토그램 크기
                            [0,256]) # 범위 # 0 초과 256 미만 정수 가짐.
    plt.plot(histogram,color=channel)
    plt.xlim([0,256])
    plt.show()

# %%
for i,channel in enumerate(colors):
    histogram =cv2.calcHist([image_rgb], # 이미지
                            [i], # 채널 인덱스
                            None, # 마스크 없음
                            [256],  # 히스토그램 크기
                            [0,256]) # 범위 # 0 초과 256 미만 정수 가짐.
    plt.plot(histogram,color=channel)
    plt.xlim([0,256])
plt.show()
